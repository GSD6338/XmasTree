# %%
# %matplotlib inline
import numpy as np
import cv2
import pandas as pd
import seaborn as sns
import math
from matplotlib import pyplot as plt
from scipy.optimize import fsolve
import sympy as smpy

# %%
# create a class of points 
class Point:
  def __init__(self, index):
    self.index = index
    self.r = None
    self.theta = None
    self.image_1_path = None
    self.image_2_path = None
    self.image_3_path = None
    self.image_4_path = None
    self.image_5_path = None
    self.image_6_path = None
    self.image_7_path = None
    self.image_8_path = None

    # actual y values 
    self.actualy = None

    # the positions to the x values
    self.i1x = None
    self.i2x = None
    self.i3x = None
    self.i4x = None
    self.i5x = None
    self.i6x = None
    self.i7x = None
    self.i8x = None
    # the positon to the y values
    self.i1y = None
    self.i2y = None
    self.i3y = None
    self.i4y = None
    self.i5y = None
    self.i6y = None
    self.i7y = None
    self.i8y = None
    # the the weights
    self.i1w = None
    self.i2w = None
    self.i3w = None
    self.i4w = None
    self.i5w = None
    self.i6w = None
    self.i7w = None
    self.i8w = None

    # equations 
    self.eqn1 = None
    self.eqn2 = None
    self.eqn3 = None
    self.eqn4 = None
    self.eqn5 = None
    self.eqn6 = None
    self.eqn7 = None
    self.eqn8 = None
  
  def printVals(self):
    print(f"the x values are: {self.i1x}, {self.i2x}, {self.i3x}, {self.i4x}, {self.i5x}, {self.i6x}, y values are: {self.i1y}, {self.i2x}, {self.i3y}, {self.i4y}, {self.i5y}, {self.i6y}, the weights are: {self.i1w}, {self.i2w}, {self.i3w}, {self.i4w}, {self.i5w}, {self.i6w}")

  def averageYs(self):
    y_s = [self.i1y*self.i1w, self.i2y*self.i2w, self.i3y*self.i3w, self.i4y*self.i4w, self.i5y*self.i5w, self.i6y*self.i6w, self.i7y*self.i7w, self.i8y*self.i8w]
    weights = [self.i1w, self.i2w, self.i3w, self.i4w, self.i5w, self.i6w, self.i7w]
    average = sum(y_s)/sum(weights)
    return average

  def averageXs(self):
    x_s = [self.i1x*self.i1w, self.i2x*self.i2w, self.i3x*self.i3w, self.i4x*self.i4w, self.i5x*self.i5w, self.i6x*self.i6w, self.i7x*self.i7w, self.i8x*self.i8w]
    weights = [self.i1w, self.i2w, self.i3w, self.i4w, self.i5w, self.i6w, self.i7w]
    average = sum(x_s)/sum(weights)
    return average

# %%
Points = []
# cause there are 500 points 
for x in range(500):
    Points.append(Point(x))

# %%
blurAmount = 41
filepath = r"D:\\CloudStorage\\OneDrive - Harvard University\\GSD 6338 TA\\Christmastree\\datset_py\\45_deg\\79_45.png"

image = cv2.imread(filepath)
orig = image.copy()
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# gray = cv2.GaussianBlur(gray, (blurAmount, blurAmount), 0)
(minVal, maxVal, minLoc, maxLoc) = cv2.minMaxLoc(gray)
image = orig.copy()
cv2.circle(image, maxLoc, 41, (255, 0, 0), 2)
plt.imshow(image)
print(maxVal)
# Out:
# 255.0

# %%
# detect an image's brigtest point given fp 
def imageBP(fp):
    image = cv2.imread(fp)
    orig = image.copy()
    gray = cv2.cvtColor(orig, cv2.COLOR_BGR2GRAY)
    # gray = cv2.GaussianBlur(gray, (blurAmount, blurAmount), 0)
    minVal, maxVal, minLoc, maxLoc = cv2.minMaxLoc(gray)
    return minVal, maxVal, minLoc, maxLoc

# %%
# create a list of images that we shall be processing 
# pat for the images 
path = r"D:\\CloudStorage\\OneDrive - Harvard University\\GSD 6338 TA\\Christmastree\\datset_py\\"

for pnt_index in range(len(Points)):
    # paths to each of the images 
    Points[pnt_index].image_1_path = path + r"0_deg\\" + f"{pnt_index}_N.png"
    Points[pnt_index].image_2_path = path + r"45_deg\\" + f"{pnt_index}_45.png"
    Points[pnt_index].image_3_path = path + r"90_deg\\" + f"{pnt_index}_90.png"
    Points[pnt_index].image_4_path = path + r"135_deg\\" + f"{pnt_index}_135.png"
    Points[pnt_index].image_5_path = path + r"180_deg\\" + f"{pnt_index}_180.png"
    Points[pnt_index].image_6_path = path + r"225_deg\\" + f"{pnt_index}_225.png"
    Points[pnt_index].image_7_path = path + r"270_deg\\" + f"{pnt_index}_270.png"
    Points[pnt_index].image_8_path = path + r"315_deg\\" + f"{pnt_index}_315.png"

# %%
examplePath = r"D:\\CloudStorage\\OneDrive - Harvard University\\GSD 6338 TA\\Christmastree\\datset_py\\315_deg\\0_315.png"
imageBP(examplePath)
# Out:
# (0.0, 80.0, (306, 98), (394, 379))

# %%
examplePath2 = Points[100].image_8_path
imageBP(examplePath2)
# Out:
# (0.0, 10.0, (321, 164), (297, 295))

# %%
# find the brightest point
for pnt_index in range(len(Points)):
    pnt = Points[pnt_index]

    minVal_1, maxVal_1, minLoc_1, (maxLoc_1_x, maxLoc_1_y) = imageBP(pnt.image_1_path)
    minVal_2, maxVal_2, minLoc_2, (maxLoc_2_x, maxLoc_2_y) = imageBP(pnt.image_2_path)
    minVal_3, maxVal_3, minLoc_3, (maxLoc_3_x, maxLoc_3_y) = imageBP(pnt.image_3_path)
    minVal_4, maxVal_4, minLoc_4, (maxLoc_4_x, maxLoc_4_y) = imageBP(pnt.image_4_path)
    minVal_5, maxVal_5, minLoc_5, (maxLoc_5_x, maxLoc_5_y) = imageBP(pnt.image_5_path)
    minVal_6, maxVal_6, minLoc_6, (maxLoc_6_x, maxLoc_6_y) = imageBP(pnt.image_6_path)
    minVal_7, maxVal_7, minLoc_7, (maxLoc_7_x, maxLoc_7_y) = imageBP(pnt.image_7_path)
    minVal_8, maxVal_8, minLoc_8, (maxLoc_8_x, maxLoc_8_y) = imageBP(pnt.image_8_path)

    # value of the the x values 
    pnt.i1x = maxLoc_1_x
    pnt.i2x = maxLoc_2_x
    pnt.i3x = maxLoc_3_x
    pnt.i4x = maxLoc_4_x
    pnt.i5x = maxLoc_5_x
    pnt.i6x = maxLoc_6_x
    pnt.i7x = maxLoc_7_x
    pnt.i8x = maxLoc_8_x

    # the y values 
    pnt.i1y = maxLoc_1_y
    pnt.i2y = maxLoc_2_y
    pnt.i3y = maxLoc_3_y
    pnt.i4y = maxLoc_4_y
    pnt.i5y = maxLoc_5_y
    pnt.i6y = maxLoc_6_y
    pnt.i7y = maxLoc_7_y
    pnt.i8y = maxLoc_8_y

    # the the weights
    pnt.i1w = maxVal_1
    pnt.i2w = maxVal_2
    pnt.i3w = maxVal_3
    pnt.i4w = maxVal_4
    pnt.i5w = maxVal_5
    pnt.i6w = maxVal_6
    pnt.i7w = maxVal_7
    pnt.i8w = maxVal_8

# %%
# for some random points plot the x and y values 
sel_index = 79
point = Points[sel_index]
x_pos = []
y_pos = []
# make another one which holds the sizes of the weights
sizes = []

x_pos.append(point.i1x)
x_pos.append(point.i2x)
x_pos.append(point.i3x)
x_pos.append(point.i4x)
x_pos.append(point.i5x)
x_pos.append(point.i6x)
x_pos.append(point.i7x)
x_pos.append(point.i8x)

y_pos.append(point.i1y)
y_pos.append(point.i2y)
y_pos.append(point.i3y)
y_pos.append(point.i4y)
y_pos.append(point.i5y)
y_pos.append(point.i6y)
y_pos.append(point.i7y)
y_pos.append(point.i8y)

sizes.append(point.i1w)
sizes.append(point.i2w)
sizes.append(point.i3w)
sizes.append(point.i4w)
sizes.append(point.i5w)
sizes.append(point.i6w)
sizes.append(point.i7w)
sizes.append(point.i8w)

sns.scatterplot(x=x_pos, y=y_pos, size=sizes)
# Out:
# <AxesSubplot:>

# %%
# find the the average Ys
for pnt in Points:
    pnt.actualy = pnt.averageYs()

# %%
average_xs = []
for pnt in Points:
    average_xs.append(pnt.averageXs())

average_xs = sum(average_xs)/(len(average_xs)*8)
print(average_xs)
# Out:
# 43.312885248842235

# %%
# manually change the center to be something else
average_xs = 300

# %%
# sanity check if the center of x is in the image??
orig = image.copy()
x1, y1 = int(average_xs), 0
x2, y2 = int(average_xs), 480
cv2.line(orig , (x1, y1), (x2, y2), (255, 255, 0), thickness=2)
plt.imshow(orig )

# %%
# adjust all the x values 
for pnt in Points:

    pnt.i1x = pnt.i1x - average_xs
    pnt.i2x = pnt.i2x - average_xs
    pnt.i3x = pnt.i3x - average_xs
    pnt.i4x = pnt.i4x - average_xs
    pnt.i5x = pnt.i5x - average_xs
    pnt.i6x = pnt.i6x - average_xs
    pnt.i7x = pnt.i7x - average_xs
    pnt.i8x = pnt.i8x - average_xs

# %%
# sanity check the plot again
# for some random points plot the x and y values 
sel_index = 300
point = Points[sel_index]
x_pos = []
y_pos = []
# make another one which holds the sizes of the weights
sizes = []

x_pos.append(point.i1x)
x_pos.append(point.i2x)
x_pos.append(point.i3x)
x_pos.append(point.i4x)
x_pos.append(point.i5x)
x_pos.append(point.i6x)
x_pos.append(point.i7x)
x_pos.append(point.i8x)

y_pos.append(point.i1y)
y_pos.append(point.i2y)
y_pos.append(point.i3y)
y_pos.append(point.i4y)
y_pos.append(point.i5y)
y_pos.append(point.i6y)
y_pos.append(point.i7y)
y_pos.append(point.i8y)

sizes.append(point.i1w)
sizes.append(point.i2w)
sizes.append(point.i3w)
sizes.append(point.i4w)
sizes.append(point.i5w)
sizes.append(point.i6w)
sizes.append(point.i7w)
sizes.append(point.i8w)

sns.scatterplot(x=x_pos, y=y_pos, size=sizes)
# Out:
# <AxesSubplot:>

# %%
# plot the y's (this should look like the increasing plot)
ypos = []

for point in Points:
    ypos.append(point.actualy)

sns.scatterplot(x=list(range(500)),y=ypos )
# Out:
# <AxesSubplot:>

# %%
# looks like there is way too much noise on the Y's at the end

# %%
x_list = []
for pnt in Points:
    x_list.append(pnt.i1x)
    x_list.append(pnt.i2x)
    x_list.append(pnt.i3x)
    x_list.append(pnt.i4x)
    x_list.append(pnt.i5x)
    x_list.append(pnt.i6x)
    x_list.append(pnt.i7x)
    x_list.append(pnt.i8x)

# get the minimum and maximum value 
print(min(x_list), max(x_list))
# Out:
# -300 339

# %%
def combinations_of_2(l):
    for i, j in zip(*np.triu_indices(len(l), 1)):
        yield l[i], l[j]

# %%
# set all the x equations so that we can end up solving them
for pnt in Points:

    r, theta = smpy.symbols('r theta')
    pnt.eqn1 = smpy.Eq(r * smpy.cos(theta), pnt.i1x)
    pnt.eqn2 = smpy.Eq(r * smpy.cos(theta + smpy.pi/4), pnt.i2x)
    pnt.eqn3 = smpy.Eq(r * smpy.cos(theta + smpy.pi/2), pnt.i3x)
    pnt.eqn4 = smpy.Eq(r * smpy.cos(theta + (3*smpy.pi)/4), pnt.i4x)
    pnt.eqn5 = smpy.Eq(r * smpy.cos(theta + smpy.pi), pnt.i5x)
    pnt.eqn6 = smpy.Eq(r * smpy.cos(theta + (5*smpy.pi)/4), pnt.i6x)
    pnt.eqn7 = smpy.Eq(r * smpy.cos(theta + (3*smpy.pi)/2), pnt.i7x)
    pnt.eqn8 = smpy.Eq(r * smpy.cos(theta + (7*smpy.pi)/4), pnt.i8x)

    #then generate n choose 2 combinations from these
    # best way is to list them out explicity 
    equns  = [pnt.eqn1, pnt.eqn2, pnt.eqn3, pnt.eqn4, pnt.eqn5, pnt.eqn6, pnt.eqn7, pnt.eqn8]
    weights = [pnt.i1w, pnt.i2w, pnt.i3w, pnt.i4w, pnt.i5w, pnt.i6w, pnt.i7w, pnt.i8w]

    # generate permutations using the custom n choose 2 
    equn_permutations = list(combinations_of_2(equns))
    weights_permutations = list(combinations_of_2(weights))

    r_s = []
    thetas = []
    w_s = []

    # generate a list of solutions 
    for eqn_perm, w in zip(equn_permutations, weights_permutations):
        e1, e2 = eqn_perm
        w1, w2 = w

        # calculate the solution
        try:
            result = smpy.nsolve([e1,e2],(r,theta), (400, 0))
            calculated_r = result[0]
            calculated_theta = result[1]
            calculated_w = w1*w2

            r_s.append(calculated_r)
            thetas.append(calculated_theta)
            w_s.append(calculated_w)
        except Exception as e:
            print(e)
    
    # for all these solutions generate a single answer by calculating the weighted averages 
    r_s_running_sum = 0
    thetas_running_sum = 0
    w_s_running_sum = 0

    for rval, thetaval, wval in zip(r_s, thetas, w_s):
        r_s_running_sum += rval * wval * wval
        thetas_running_sum += thetaval * wval * wval
        w_s_running_sum += wval * wval

    # finall set the points r and theta value
    pnt.r = r_s_running_sum/(w_s_running_sum + 0.000000001)
    pnt.theta = thetas_running_sum/(w_s_running_sum + 0.000000001)


    # sns.scatterplot(x=r_s, y=thetas, size=w_s)
    # sns.scatterplot(x=[pnt.r], y=[pnt.theta], marker='o')
    # break
    
    print("Done with one point!")
# Out:
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (0.00034595825820492350609 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Could not find root within given tolerance. (2.40189364720956891611e-10 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# Could not find root within given tolerance. (5.1241281073787993411e-10 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (1.46436199915532548878e-18 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (1.64156755940634995749e-9 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (3011.5237330900584203 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (0.000054697333361944417421 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (3.4090173194721030159e-16 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (1.17833149811224814015e-14 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (0.025424936024627579417 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (0.0007806080701650705958 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (1.02084393567408747283e-18 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (0.0000664275092435662967166 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (3.4572221758275260794e-14 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# Could not find root within given tolerance. (0.0000062790483449682979767 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (488.046798902271310334 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# Could not find root within given tolerance. (7.88902213365640124223e-9 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (7.0350262300630669388e-19 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Could not find root within given tolerance. (9.53472396979519663639e-15 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (1.65585631652448774442e-8 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (0.0000354916508441407007586 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (5.98953813164359636595e-15 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (6.40771052454134657605e-7 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Could not find root within given tolerance. (1.42532071083513598076e-13 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (2.64016522821003092679e-16 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (1.47870031146322373483e-18 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (4.95298166222115136271e-19 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (0.0000243235195203653737628 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (1.02591811324635471065e-15 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# Could not find root within given tolerance. (1.02591811324635471065e-15 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# Could not find root within given tolerance. (1.36089956135642015713e-8 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (7896.92930470840844529 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# Could not find root within given tolerance. (1.14186778205261614483e-16 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (0.0000243235195203653737628 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (3.20912401485262365329e-13 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (3.11494544194523232593e-12 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (1.85500991772836147485e-14 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (5.84569484424505540353e-16 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Could not find root within given tolerance. (0.000166902195724551936262 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (1142.45709666350329307 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (3.65273991267953827097e-11 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (0.0113549541670471067655 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (5.32702229023291343981e-14 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (5.33555042660634956458e-14 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (2.20914394269226445254e-19 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (3.01118825448082372752e-12 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (0.000054697333361944419601 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (3.20566366625065594166e-7 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (2.45062189962463817515e-16 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (2.93829619121164234503e-8 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (0.00000200848758003202932626 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (9.50144921037285745828e-8 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (2.41380513983522880453e-8 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (2.03688847963430547281e-16 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (0.00000246045110278691379633 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (4.15493195524030813729e-12 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (0.000054697333361944417421 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (3.66499597765272119964e-19 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Could not find root within given tolerance. (3.6487977373922572075 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (2.66603114179801541355e-10 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# Could not find root within given tolerance. (1.85500991772836147485e-14 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (1.82444974064560964773e-11 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (3.56655331221787907405e-10 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (1.47490873632644768596e-14 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Could not find root within given tolerance. (0.0000243235195203653737628 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (3.6428501982382399464e-16 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# Could not find root within given tolerance. (1.37674007816553068082e-18 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (32469.2550672131754401 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (0.0000326892894663967224894 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (1.03899815170277932083e-15 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# Could not find root within given tolerance. (2.54862132994003654704e-16 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (8510.6156533190256922 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# Could not find root within given tolerance. (1.16927148934303413939e-10 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (1.94871311802571227018e-9 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (3.02330323553751480482e-18 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (5.46916409739170281042e-18 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (3.58221327281014668944e-11 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (0.00044440119519161180873 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (4.73753720243025527583e-13 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (3.94622554145171357236e-8 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (2.64016522819241417535e-16 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Could not find root within given tolerance. (4.91596623373294620708e-12 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# Could not find root within given tolerance. (2.64016522821003092679e-16 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (3.80477750597834868719e-18 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (5.09921268005496995221e-10 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (2.30420561910170265651e-18 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# Could not find root within given tolerance. (1.47490873632644768596e-14 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (4.29016847681416221223e-13 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (1.77682957326317402404e-11 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (524.260085380899964646 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# matrix is numerically singular
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (9.63297239325538405815e-13 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# Could not find root within given tolerance. (1.6291705325925732359e-9 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Could not find root within given tolerance. (3.93191320327451197785e-10 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (0.00147547863819414344012 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (8.95870509935273187595e-14 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (51.7185687268131068805 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (1.8418261261635114403e-11 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# Could not find root within given tolerance. (0.12405904066816303194 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (5.39625066013877439654e-7 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (0.0000239612449133908988866 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# Could not find root within given tolerance. (1.19744067289009201448e-9 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# ...
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (1.56954801256940625075 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (0.0000280691214799226912013 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (0.14139051304867369666 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (3.26899741480098756302e-19 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (22.2627382599198331003 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (1.92124143786554994381e-7 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (0.0173262262899277161131 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (7.24114963352585077131e-11 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (1.41990859851410683151e-18 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (2.81837821642405026758e-13 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Could not find root within given tolerance. (0.0226952754550288480744 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (5.7101253920664920198e-9 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (2.26017066871267081811e-7 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# Could not find root within given tolerance. (3.80477750597834868719e-18 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (1.31554275159201102088e-12 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (1.00219030455259796021e-9 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (0.0000745167287317082228266 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (9.49120823484465344811e-9 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (32469.2550672131754401 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (2.10972962187125071767e-8 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (1.92955776176271952959e-11 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (1.47490873632644768596e-14 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# Could not find root within given tolerance. (1565.69463462694597366 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (4.23468149025306523442e-19 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (0.000134104744762352970007 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (6.00757098401790207773e-7 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (2.76112392200253351736e-12 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (1.56322103801690875511e-18 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# Could not find root within given tolerance. (6.29833208560247099165e-8 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (1.47490873632644768596e-14 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (2.18117591470509467083e-15 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (2.44229636458517283617e-19 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (1.92955776176271952959e-11 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Could not find root within given tolerance. (1.17967146969655875301e-18 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# Done with one point!
# matrix is numerically singular
# Could not find root within given tolerance. (0.0000151490675948994771023 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!
# matrix is numerically singular
# matrix is numerically singular
# '>=' not supported between instances of 'NoneType' and 'int'
# Done with one point!

# %%
# finally save all the points out as a csv. 
# here we want a specific datastructure - the x value, the y value, the z value, r and theta
Data = {"index":[], "x":[], "y":[], "z": [], "r":[], "theta":[]}

for i in range(len(Points)):
    pnt = Points[i]
    Data["index"].append(i)
    Data["x"].append(pnt.r * math.cos(pnt.theta))
    Data["y"].append(pnt.r * math.sin(pnt.theta))
    Data["z"].append(pnt.actualy)
    Data["r"].append(pnt.r)
    Data["theta"].append(pnt.theta)

# now make this a dataframe 
df = pd.DataFrame.from_dict(Data)
df.to_csv("coordinates.csv", index=False)

# %%
with open('coords_mattForm_raw.txt', 'w') as f:
    for pnt in Points:
        line = f"[{pnt.r * math.cos(pnt.theta)}, {pnt.r * math.sin(pnt.theta)}, {pnt.actualy}] \n"
        f.write(line)
